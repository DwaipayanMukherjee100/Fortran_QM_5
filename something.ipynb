# %% [markdown]
# This is a rough file , i made to check my plots as plotting with GNUPLOT often takes away

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
z=np.loadtxt("sg.txt")
plt.hist(z,bins=10);
# Out:
# (array([500.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0., 500.]),
#  array([-4.44266680e-05, -3.55413344e-05, -2.66560008e-05, -1.77706672e-05,
#         -8.88533360e-06, -6.77626358e-21,  8.88533360e-06,  1.77706672e-05,
#          2.66560008e-05,  3.55413344e-05,  4.44266680e-05]),
#  <BarContainer object of 10 artists>)
