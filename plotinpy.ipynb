# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
data=np.loadtxt("numer3.txt")
x=data[:,0]
y=data[:,1]
plt.plot(x,y)

# %%
print(y[len(y)-1])
# Out:
# 5.730727176800828e-06

# %%
import scipy.integrate as si
import numpy as np
print(si.simpson(y*y, x))
# Out:
# 0.9999999999999841
